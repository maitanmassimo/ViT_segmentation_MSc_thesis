# %%
#!pip3 install torch torchvision

# %%
import os
import tensorflow as tf
#import numpy as np
#import pandas as pd
#import json
#from sklearn.model_selection import KFold

SEED = 1234
tf.random.set_seed(SEED)

cwd = os.getcwd() #get current working directory
physical_devices = tf.config.list_physical_devices('GPU') 
#tf.config.experimental.set_memory_growth(physical_devices[0], True)

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#!pip install torch==1.9.0

# %%
#!pip install git+https://github.com/rstrudel/segmenter.git

# %%
#!pip install --ignore-installed PyYAML
# Out:
# ...
#   Using cached PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
# ...

# %%
# !unzip '/content/drive/My Drive/Dataset/brats2019_slice_testing.tfrecords'
# !unzip '/content/drive/My Drive/Dataset/brats2019_slice_training.tfrecords'
# !unzip '/content/drive/My Drive/Dataset/brats2019_slice_validation.tfrecords'
# Out:
# unzip:  cannot find or open /content/drive/My Drive/Dataset/brats2019_slice_testing.tfrecords, /content/drive/My Drive/Dataset/brats2019_slice_testing.tfrecords.zip or /content/drive/My Drive/Dataset/brats2019_slice_testing.tfrecords.ZIP.
# unzip:  cannot find or open /content/drive/My Drive/Dataset/brats2019_slice_training.tfrecords, /content/drive/My Drive/Dataset/brats2019_slice_training.tfrecords.zip or /content/drive/My Drive/Dataset/brats2019_slice_training.tfrecords.ZIP.
# unzip:  cannot find or open /content/drive/My Drive/Dataset/brats2019_slice_validation.tfrecords, /content/drive/My Drive/Dataset/brats2019_slice_validation.tfrecords.zip or /content/drive/My Drive/Dataset/brats2019_slice_validation.tfrecords.ZIP.

# %% [markdown]
# # RUNNING

# %%
#set environment variables
os.environ['DATASET'] = "/content/drive/MyDrive/Dataset/"
os.environ['FORCE_CUDA'] = "1"
os.environ['DATASET']
# Out:
# '/content/drive/MyDrive/Dataset/'

# %%
#if you want to clone the repo
# !git clone https://github.com/rstrudel/segmenter.git
# Out:
# Cloning into 'segmenter'...
# remote: Enumerating objects: 268, done.
# remote: Counting objects: 100% (268/268), done.
# remote: Compressing objects: 100% (219/219), done.
# remote: Total 268 (delta 121), reused 169 (delta 48), pack-reused 0
# Receiving objects: 100% (268/268), 15.34 MiB | 13.81 MiB/s, done.
# Resolving deltas: 100% (121/121), done.

# %%
# %cd /content/drive/My Drive/Segmenter/segmenter
# Out:
# /content/drive/My Drive/Segmenter/segmenter

# %%
# %cd /content/drive/My Drive/Dataset/ade20k/ADEChallengeData2016

# %ls -l
# Out:
# /content/drive/My Drive/Dataset/ade20k/ADEChallengeData2016
# total 646
# drwx------ 4 root root   4096 Apr  7 09:48 annotations/
# drwx------ 4 root root   4096 Apr  7 09:48 images/
# -rw------- 1 root root   5689 Apr  7 09:45 objectInfo150.txt
# -rw------- 1 root root 646429 Apr  7 09:45 sceneCategories.txt

# %%
#only once, if you need to download the ade20k dataset
# !python -m segm.scripts.prepare_ade20k $DATASET
# Out:
# ...
# 944710KB [05:15, 2994.49KB/s]
# ...
# 100% 206856/206856 [00:48<00:00, 4265.40KB/s]

# %%
# !python -m segm.eval.miou "/content/drive/My Drive/Models/Pre-trained/PASCAL - Seg-L-Mask16/checkpoint.pth" ade20k --singlescale
# Out:
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/usr/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/content/drive/My Drive/Segmenter/segmenter/segm/eval/miou.py", line 13, in <module>
#     from segm.utils import distributed
#   File "/content/drive/My Drive/Segmenter/segmenter/segm/utils/distributed.py", line 2, in <module>
#     import hostlist
# ModuleNotFoundError: No module named 'hostlist'

# %%
# !python -m segm.scripts.show_attn_map "/content/drive/My Drive/Models/Pre-trained/PASCAL - Seg-L-Mask16/checkpoint.pth" \
"$DATASET/ade20k/ADEChallengeData2016/images/training/ADE_train_00000005.jpg" output_dir/ --layer-id 1 --dec --cls
# Out:
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/usr/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/content/drive/MyDrive/Segmenter/segmenter/segm/scripts/show_attn_map.py", line 2, in <module>
#     import einops
# ModuleNotFoundError: No module named 'einops'

# %%
# !dir
# Out:
# attn_maps_dec.png  gifs     output_dir	  README.md	    segm     setup.py
# attn_maps_enc.png  LICENSE  overview.png  requirements.txt  segmaps

# %%
#!python -m segm.inference --model-path "/content/drive/My Drive/Models/Pre-trained/PASCAL - Seg-L-Mask16/checkpoint.pth" -i images/ -o segmaps/
