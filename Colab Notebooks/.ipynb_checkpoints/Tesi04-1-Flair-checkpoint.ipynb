# %% [markdown]
# Con questo notebook alleniamo il primo segmenter, quello che utilizzerà le immagini "flair" del dataset.

# %%
import os
import tensorflow as tf
import matplotlib.pyplot as plt


SEED = 1234
tf.random.set_seed(SEED)

cwd = os.getcwd() #get current working directory
physical_devices = tf.config.list_physical_devices('GPU') 
#physical_devices = tf.config.list_physical_devices('CPU')

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
tf.config.list_physical_devices()
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'),
#  PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# # RUNNING

# %% [markdown]
# Se abbiamo eseguito correttamente il notebook Tesi-04-dispatch, dovremmo avere la cartella Extracted/Flair con al suo interno le immagini, convertite in 3 canali, della vista "flair" del dataset BraTS (slice).
#
# Per prima cosa, proviamo a usare il segmenter pre-trainato direttamente su queste immagini

# %%
# %cd /content/drive/My Drive/Segmenter/segmenter
# !pip install .
# !pip install --ignore-installed PyYAML

# %%
#!python -m segm.inference --model-path "/content/drive/My Drive/Models/Pre-trained/PASCAL - Seg-L-Mask16/checkpoint.pth" -i "/content/drive/My Drive/Immagine" -o segmaps/
# !python -m segm.inference --model-path "~/Google\ Drive/Il mio Drive//Models/Pre-trained/PASCAL - Seg-L-Mask16/checkpoint.pth" -i "/content/drive/My Drive/Immagine" -o segmaps/
# Out:
# libc++abi: terminating with uncaught exception of type std::length_error: vector

# %% [markdown]
# Il risultato è abbastanza un disastro:
#
# ![test_flair_orig.png](data:image/png;base64,...)![test_flair.png](data:image/png;base64,...)

# %% [markdown]
# I possibili problemi sono
#
#
# * Troppe classi? Ce ne sono 60...
#   * potrei provare a modificare il numero di classi...
#     * problema: quante classi ha il nostro dataset???
# * Non c'è un minimo di fine tuning!
#   * problema: come si fa il training??

# %% [markdown]
# Una possibile soluzione a questo problema potrebbe essere di utilizzare una versione del segmenter che abbia il numero di classi uguale a quelle del nostro dataset.
#
# Problema: andrebbe TRAINATO DA ZERO!
#
# Proviamoci.

# %% [markdown]
# Per prima cosa, dobbiamo cercare di capire quante classi ha il nostro dataset. Per fare ciò, prendiamo tutte le immagini e calcoliamone i valori distinti

# %%
dataset_name = os.path.join('/content/drive/My Drive/Unzipped/', "brats2019_slice_training_tfrecords/brats2019_slice_training.tfrecords")
raw_dataset = tf.data.TFRecordDataset(dataset_name)
import numpy as np

count = 0


image_list = []

for raw_record in raw_dataset:
    example = tf.train.Example()
    example.ParseFromString(raw_record.numpy())

    parsed = tf.train.Example.FromString(raw_record.numpy())
    feature = parsed.features.feature

    raw_img_seg = feature['seg'].bytes_list.value[0]
    img_seg = tf.image.decode_png(raw_img_seg)

    image_list.append(img_seg)

tensor = np.uint8(image_list)
print(tensor.shape)
print((np.unique(tensor)))
# Out:
# (14894, 180, 180, 1)
# [0 1 2 4]

# %% [markdown]
# Abbiamo appurato che questo dataset ha 4 valori distinti! Pertanto, dovremo modificare il segmenter in modo da poter avere 4 classi!

# %%
os.environ['DATASET_DRIVE'] = "/content/drive/MyDrive/Extracted/"

#INSERIRE QUI PATH PER DATASET LOCALE
#os.environ['DATASET_LOCALE'] = "/Massimo/Politecnico/Magistrale/Tesi/Dataset/Extracted/"
os.environ['DATASET_LOCALE_CUSTOM'] = "~/Google\ Drive/Il mio Drive/Dataset/Extracted"
os.environ['DATASET_LOCALE_ADE20K'] = "~/Google\ Drive/Il mio Drive/Dataset/ade20k"

# %%
#%cd /content/drive/My Drive/MMSegmentation

#!rm -rf mmsegmentation
#!git clone https://github.com/open-mmlab/mmsegmentation.git
#%cd MMSegmentation
#!pip install -e

# %%
# !conda config --add channels conda-forge
# !conda config --add channels matsci
# !conda config --add channels abinit
# Out:
# Warning: 'conda-forge' already in 'channels' list, moving to the top
# Warning: 'matsci' already in 'channels' list, moving to the top
# Warning: 'abinit' already in 'channels' list, moving to the top

# %%
# !conda update conda
#%cd /content/drive/My Drive/Segmenter/custom_dataset_segmenter
# %cd ~/Google\ Drive/Il mio Drive/Segmenter/custom_dataset_segmenter
# !ls
#cd ~/Google\ Drive/Il mio Drive/Segmenter/segmenter
#!pip install -v -e 
#!pip install .
#!pip install --ignore-installed PyYAML

# !conda install --file requirements.txt
# !conda install PyYAML --yes
# Out:
# PackageNotInstalledError: Package is not installed in prefix.
#   prefix: /Users/massimomaitan/miniforge3/envs/env_thesis
#   package name: conda
#
#
# /Users/massimomaitan/Library/CloudStorage/GoogleDrive-maitanmassimothesis@gmail.com/Il mio Drive/Segmenter/custom_dataset_segmenter
# LICENSE           build             overview.png      segmaps
# README.md         gifs              requirements.txt  setup.py
# attn_maps_dec.png mmsegmentation    segm
# attn_maps_enc.png output_dir        segm.egg-info
# Collecting package metadata (current_repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Collecting package metadata (repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
#
# PackagesNotFoundError: The following packages are not available from current channels:
#
#   - mmcv==1.3.8
#   - mmsegmentation==0.14.1
#   - torch
#
# Current channels:
#
#   - https://conda.anaconda.org/abinit/osx-arm64
#   - https://conda.anaconda.org/abinit/noarch
#   - https://conda.anaconda.org/matsci/osx-arm64
#   - https://conda.anaconda.org/matsci/noarch
#   - https://conda.anaconda.org/conda-forge/osx-arm64
#   - https://conda.anaconda.org/conda-forge/noarch
#
# To search for alternate channels that may provide the conda package you're
# looking for, navigate to
#
#     https://anaconda.org
#
# and use the search bar at the top of the page.
#
#
# Collecting package metadata (current_repodata.json): done
# Solving environment: /
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - conda-forge/noarch::notebook-shim==0.1.0=pyhd8ed1ab_0
#   - conda-forge/noarch::bleach==4.1.0=pyhd8ed1ab_0
#   - conda-forge/noarch::python-dateutil==2.8.2=pyhd8ed1ab_0
#   - conda-forge/noarch::google-auth==2.6.2=pyh6c4a22f_0
#   - conda-forge/osx-arm64::jupyter==1.0.0=py39h2804cbe_7
#   - conda-forge/osx-arm64::widgetsnbextension==3.6.0=py39h2804cbe_0
#   - conda-forge/noarch::ipywidgets==7.7.0=pyhd8ed1ab_0
#   - apple/osx-arm64::tensorflow-deps==2.8.0=0
#   - conda-forge/noarch::jupyterlab==3.3.2=pyhd8ed1ab_0
#   - conda-forge/noarch::jupyterlab_server==2.12.0=pyhd8ed1ab_0
#   - conda-forge/noarch::stack_data==0.2.0=pyhd8ed1ab_0
#   - conda-forge/osx-arm64::matplotlib==3.5.1=py39hdf13c20_0
#   - conda-forge/osx-arm64::ipython==8.2.0=py39h2804cbe_0
#   - conda-forge/noarch::jupyter_console==6.4.3=pyhd8ed1ab_0
#   - conda-forge/osx-arm64::yarl==1.7.2=py39hb18efdd_2
#   - conda-forge/osx-arm64::ipykernel==6.12.1=py39h32adebf_0
#   - conda-forge/noarch::nbclient==0.5.13=pyhd8ed1ab_0
#   - conda-forge/noarch::jupyter_client==7.2.1=pyhd8ed1ab_0
#   - conda-forge/osx-arm64::pandas==1.4.2=py39h2666b31_0
#   - conda-forge/noarch::asttokens==2.0.5=pyhd8ed1ab_0
#   - conda-forge/osx-arm64::nbconvert==6.4.5=py39h2804cbe_0
#   - conda-forge/noarch::notebook==6.4.10=pyha770c72_0
#   - conda-forge/noarch::google-colab==1.0.0=pyh44b312d_0
#   - conda-forge/osx-arm64::aiohttp==3.8.1=py39hb18efdd_1
#   - conda-forge/osx-arm64::matplotlib-base==3.5.1=py39h5aa4fe7_0
#   - conda-forge/noarch::jupyter_server==1.16.0=pyhd8ed1ab_0
#   - conda-forge/noarch::nbclassic==0.3.7=pyhd8ed1ab_0
#   - conda-forge/osx-arm64::anyio==3.5.0=py39h2804cbe_0
#   - conda-forge/osx-arm64::grpcio==1.45.0=py39hcf421d0_0
#   - conda-forge/noarch::pyu2f==0.1.5=pyhd8ed1ab_0
# done
#
# ## Package Plan ##
#
#   environment location: /Users/massimomaitan/miniforge3/envs/env_thesis
#
#   added / updated specs:
#     - pyyaml
#
#
# The following NEW packages will be INSTALLED:
#
#   idna               conda-forge/noarch::idna-3.3-pyhd8ed1ab_0
#   requests           conda-forge/noarch::requests-2.27.1-pyhd8ed1ab_0
#   six                conda-forge/noarch::six-1.16.0-pyh6c4a22f_0
#   urllib3            conda-forge/noarch::urllib3-1.26.9-pyhd8ed1ab_0
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
# !conda list
# Out:
# # packages in environment at /Users/massimomaitan/miniforge3/envs/env_thesis:
# #
# # Name                    Version                   Build  Channel
# absl-py                   1.0.0                    pypi_0    pypi
# addict                    2.4.0                    pypi_0    pypi
# aiohttp                   3.8.1            py39hb18efdd_1    conda-forge
# aiosignal                 1.2.0              pyhd8ed1ab_0    conda-forge
# anyio                     3.5.0            py39h2804cbe_0    conda-forge
# appnope                   0.1.3              pyhd8ed1ab_0    conda-forge
# argon2-cffi               21.3.0             pyhd8ed1ab_0    conda-forge
# argon2-cffi-bindings      21.2.0           py39h5161555_1    conda-forge
# asttokens                 2.0.5              pyhd8ed1ab_0    conda-forge
# astunparse                1.6.3                    pypi_0    pypi
# async-timeout             4.0.2              pyhd8ed1ab_0    conda-forge
# attrs                     21.4.0             pyhd8ed1ab_0    conda-forge
# babel                     2.9.1              pyh44b312d_0    conda-forge
# backcall                  0.2.0              pyh9f0ad1d_0    conda-forge
# backports                 1.0                        py_2    conda-forge
# backports.functools_lru_cache 1.6.4              pyhd8ed1ab_0    conda-forge
# beautifulsoup4            4.10.0             pyha770c72_0    conda-forge
# bleach                    4.1.0              pyhd8ed1ab_0    conda-forge
# brotli                    1.0.9                h1c322ee_7    conda-forge
# brotli-bin                1.0.9                h1c322ee_7    conda-forge
# brotlipy                  0.7.0           py39hb18efdd_1004    conda-forge
# bzip2                     1.0.8                h3422bc3_4    conda-forge
# c-ares                    1.18.1               h3422bc3_0    conda-forge
# ca-certificates           2021.10.8            h4653dfc_0    conda-forge
# cached-property           1.5.2                hd8ed1ab_1    conda-forge
# cached_property           1.5.2              pyha770c72_1    conda-forge
# cachetools                5.0.0              pyhd8ed1ab_0    conda-forge
# certifi                   2021.10.8                pypi_0    pypi
# cffi                      1.15.0           py39h52b1de0_0    conda-forge
# chardet                   3.0.4                    pypi_0    pypi
# charset-normalizer        2.0.12             pyhd8ed1ab_0    conda-forge
# click                     8.1.2                    pypi_0    pypi
# cryptography              36.0.2           py39hbe5e4b8_1    conda-forge
# cycler                    0.11.0             pyhd8ed1ab_0    conda-forge
# debugpy                   1.5.1            py39hfb83b0d_0    conda-forge
# decorator                 5.1.1              pyhd8ed1ab_0    conda-forge
# defusedxml                0.7.1              pyhd8ed1ab_0    conda-forge
# einops                    0.4.1                    pypi_0    pypi
# entrypoints               0.4                pyhd8ed1ab_0    conda-forge
# executing                 0.8.3              pyhd8ed1ab_0    conda-forge
# flatbuffers               2.0                      pypi_0    pypi
# flit-core                 3.7.1              pyhd8ed1ab_0    conda-forge
# fonttools                 4.31.2           py39hb18efdd_1    conda-forge
# freetype                  2.10.4               h17b34a0_1    conda-forge
# frozenlist                1.3.0            py39hb18efdd_1    conda-forge
# future                    0.18.2           py39h2804cbe_5    conda-forge
# gast                      0.5.3                    pypi_0    pypi
# giflib                    5.2.1                h27ca646_2    conda-forge
# google-auth               1.4.2                    pypi_0    pypi
# google-auth-oauthlib      0.4.6                    pypi_0    pypi
# google-colab              1.0.0              pyh44b312d_0    conda-forge
# google-pasta              0.2.0                    pypi_0    pypi
# grpcio                    1.45.0           py39hcf421d0_0    conda-forge
# h5py                      3.6.0           nompi_py39hd982b79_100    conda-forge
# hdf5                      1.12.1          nompi_hf9525e8_104    conda-forge
# idna                      2.8                      pypi_0    pypi
# importlib-metadata        4.11.3           py39h2804cbe_1    conda-forge
# importlib_resources       5.6.0              pyhd8ed1ab_0    conda-forge
# ipykernel                 6.12.1           py39h32adebf_0    conda-forge
# ipython                   8.2.0            py39h2804cbe_0    conda-forge
# ipython_genutils          0.2.0                      py_1    conda-forge
# ipywidgets                7.7.0              pyhd8ed1ab_0    conda-forge
# jbig                      2.1               h3422bc3_2003    conda-forge
# jedi                      0.18.1           py39h2804cbe_1    conda-forge
# jinja2                    3.1.1              pyhd8ed1ab_0    conda-forge
# joblib                    1.1.0                    pypi_0    pypi
# jpeg                      9e                   h3422bc3_0    conda-forge
# json5                     0.9.5              pyh9f0ad1d_0    conda-forge
# jsonschema                4.4.0              pyhd8ed1ab_0    conda-forge
# jupyter                   1.0.0            py39h2804cbe_7    conda-forge
# jupyter-http-over-ws      0.0.8                    pypi_0    pypi
# jupyter_client            7.2.1              pyhd8ed1ab_0    conda-forge
# jupyter_console           6.4.3              pyhd8ed1ab_0    conda-forge
# jupyter_core              4.9.2            py39h2804cbe_0    conda-forge
# jupyter_server            1.16.0             pyhd8ed1ab_0    conda-forge
# jupyterlab                3.3.2              pyhd8ed1ab_0    conda-forge
# jupyterlab_pygments       0.1.2              pyh9f0ad1d_0    conda-forge
# jupyterlab_server         2.12.0             pyhd8ed1ab_0    conda-forge
# jupyterlab_widgets        1.1.0              pyhd8ed1ab_0    conda-forge
# keras                     2.8.0                    pypi_0    pypi
# keras-preprocessing       1.1.2                    pypi_0    pypi
# kiwisolver                1.4.2            py39h2c803a9_1    conda-forge
# krb5                      1.19.3               hf9b2bbe_0    conda-forge
# lcms2                     2.12                 had6a04f_0    conda-forge
# lerc                      3.0                  hbdafb3b_0    conda-forge
# libblas                   3.9.0           14_osxarm64_openblas    conda-forge
# libbrotlicommon           1.0.9                h1c322ee_7    conda-forge
# libbrotlidec              1.0.9                h1c322ee_7    conda-forge
# libbrotlienc              1.0.9                h1c322ee_7    conda-forge
# libcblas                  3.9.0           14_osxarm64_openblas    conda-forge
# libclang                  13.0.0                   pypi_0    pypi
# libcurl                   7.82.0               hb0e6552_0    conda-forge
# libcxx                    13.0.1               h6a5c8ee_0    conda-forge
# libdeflate                1.10                 h3422bc3_0    conda-forge
# libedit                   3.1.20191231         hc8eb9b7_2    conda-forge
# libev                     4.33                 h642e427_1    conda-forge
# libffi                    3.4.2                h3422bc3_5    conda-forge
# libgfortran               5.0.0.dev0      11_0_1_hf114ba7_23    conda-forge
# libgfortran5              11.0.1.dev0         hf114ba7_23    conda-forge
# liblapack                 3.9.0           14_osxarm64_openblas    conda-forge
# libnghttp2                1.47.0               he723fca_0    conda-forge
# libopenblas               0.3.20          openmp_h2209c59_0    conda-forge
# libpng                    1.6.37               hf7e6567_2    conda-forge
# libprotobuf               3.19.4               hccf11d3_0    conda-forge
# libsodium                 1.0.18               h27ca646_1    conda-forge
# libssh2                   1.10.0               hb80f160_2    conda-forge
# libtiff                   4.3.0                h77dc3b6_3    conda-forge
# libwebp                   1.2.2                h0d20362_0    conda-forge
# libwebp-base              1.2.2                h3422bc3_1    conda-forge
# libxcb                    1.13              h9b22ae9_1004    conda-forge
# libzlib                   1.2.11            h90dfc92_1014    conda-forge
# llvm-openmp               13.0.1               h455960f_1    conda-forge
# lz4-c                     1.9.3                hbdafb3b_1    conda-forge
# markdown                  3.3.6                    pypi_0    pypi
# markupsafe                2.1.1            py39hb18efdd_1    conda-forge
# matplotlib                3.5.1            py39hdf13c20_0    conda-forge
# matplotlib-base           3.5.1            py39h5aa4fe7_0    conda-forge
# matplotlib-inline         0.1.3              pyhd8ed1ab_0    conda-forge
# mistune                   0.8.4           py39h5161555_1005    conda-forge
# mmcv                      1.3.8                    pypi_0    pypi
# mmsegmentation            0.14.1                   pypi_0    pypi
# multidict                 6.0.2            py39hb18efdd_1    conda-forge
# munkres                   1.1.4              pyh9f0ad1d_0    conda-forge
# nbclassic                 0.3.7              pyhd8ed1ab_0    conda-forge
# nbclient                  0.5.13             pyhd8ed1ab_0    conda-forge
# nbconvert                 6.4.5            py39h2804cbe_0    conda-forge
# nbformat                  5.3.0              pyhd8ed1ab_0    conda-forge
# ncurses                   6.3                  hc470f4d_0    conda-forge
# nest-asyncio              1.5.5              pyhd8ed1ab_0    conda-forge
# ninja                     1.10.2               hc021e02_1    conda-forge
# notebook                  6.4.10             pyha770c72_0    conda-forge
# notebook-shim             0.1.0              pyhd8ed1ab_0    conda-forge
# numpy                     1.21.5           py39h47fb9ce_0    conda-forge
# oauthlib                  3.2.0                    pypi_0    pypi
# opencv-python             4.5.5.64                 pypi_0    pypi
# openjpeg                  2.4.0                h062765e_1    conda-forge
# openssl                   1.1.1n               h90dfc92_0    conda-forge
# opt-einsum                3.3.0                    pypi_0    pypi
# packaging                 21.3               pyhd8ed1ab_0    conda-forge
# pandas                    1.4.2            py39h2666b31_0    conda-forge
# pandocfilters             1.5.0              pyhd8ed1ab_0    conda-forge
# parso                     0.8.3              pyhd8ed1ab_0    conda-forge
# pexpect                   4.8.0              pyh9f0ad1d_2    conda-forge
# pickleshare               0.7.5                   py_1003    conda-forge
# pillow                    9.1.0            py39hd72dd6b_0    conda-forge
# pip                       22.0.4             pyhd8ed1ab_0    conda-forge
# portpicker                1.2.0                    pypi_0    pypi
# prettytable               3.2.0                    pypi_0    pypi
# prometheus_client         0.14.0             pyhd8ed1ab_0    conda-forge
# prompt-toolkit            3.0.29             pyha770c72_0    conda-forge
# prompt_toolkit            3.0.29               hd8ed1ab_0    conda-forge
# protobuf                  3.20.0                   pypi_0    pypi
# psutil                    5.9.0            py39hb18efdd_1    conda-forge
# pthread-stubs             0.4               h27ca646_1001    conda-forge
# ptyprocess                0.7.0              pyhd3deb0d_0    conda-forge
# pure_eval                 0.2.2              pyhd8ed1ab_0    conda-forge
# pyasn1                    0.4.8                      py_0    conda-forge
# pyasn1-modules            0.2.8                    pypi_0    pypi
# pycparser                 2.21               pyhd8ed1ab_0    conda-forge
# pygments                  2.11.2             pyhd8ed1ab_0    conda-forge
# pyopenssl                 22.0.0             pyhd8ed1ab_0    conda-forge
# pyparsing                 3.0.7              pyhd8ed1ab_0    conda-forge
# pyrsistent                0.18.1           py39hb18efdd_1    conda-forge
# pysocks                   1.7.1            py39h2804cbe_5    conda-forge
# python                    3.9.12          hfc7342c_1_cpython    conda-forge
# python-dateutil           2.8.2              pyhd8ed1ab_0    conda-forge
# python-fastjsonschema     2.15.3             pyhd8ed1ab_0    conda-forge
# python-hostlist           1.21                     pypi_0    pypi
# python_abi                3.9                      2_cp39    conda-forge
# pytorch                   1.10.2          cpu_py39hbfdb42d_0    conda-forge
# pytz                      2022.1             pyhd8ed1ab_0    conda-forge
# pyu2f                     0.1.5              pyhd8ed1ab_0    conda-forge
# pyyaml                    6.0              py39hb18efdd_4    conda-forge
# pyzmq                     22.3.0           py39h7a4232c_2    conda-forge
# readline                  8.1                  hedafd6a_0    conda-forge
# requests                  2.21.0                   pypi_0    pypi
# requests-oauthlib         1.3.1                    pypi_0    pypi
# rsa                       4.8                pyhd8ed1ab_0    conda-forge
# scikit-learn              1.0.2                    pypi_0    pypi
# scipy                     1.8.0                    pypi_0    pypi
# segm                      0.0.1                    pypi_0    pypi
# send2trash                1.8.0              pyhd8ed1ab_0    conda-forge
# setuptools                62.0.0           py39h2804cbe_0    conda-forge
# simplegeneric             0.8.1                    pypi_0    pypi
# six                       1.15.0                   pypi_0    pypi
# sleef                     3.5.1                h156473d_2    conda-forge
# sniffio                   1.2.0            py39h2804cbe_3    conda-forge
# soupsieve                 2.3.1              pyhd8ed1ab_0    conda-forge
# sqlite                    3.37.1               h7e3ccbd_0    conda-forge
# stack_data                0.2.0              pyhd8ed1ab_0    conda-forge
# tensorboard               2.8.0                    pypi_0    pypi
# tensorboard-data-server   0.6.1                    pypi_0    pypi
# tensorboard-plugin-wit    1.8.1                    pypi_0    pypi
# tensorflow-deps           2.8.0                         0    apple
# tensorflow-macos          2.8.0                    pypi_0    pypi
# tensorflow-metal          0.4.0                    pypi_0    pypi
# termcolor                 1.1.0                    pypi_0    pypi
# terminado                 0.13.3           py39h2804cbe_1    conda-forge
# testpath                  0.6.0              pyhd8ed1ab_0    conda-forge
# tf-estimator-nightly      2.8.0.dev2021122109          pypi_0    pypi
# threadpoolctl             3.1.0                    pypi_0    pypi
# timm                      0.4.12                   pypi_0    pypi
# tk                        8.6.12               he1e0b03_0    conda-forge
# torch-geometric           2.0.4                    pypi_0    pypi
# torch-scatter             2.0.9                    pypi_0    pypi
# torch-sparse              0.6.13                   pypi_0    pypi
# torchvision               0.12.0                   pypi_0    pypi
# tornado                   6.1              py39hb18efdd_3    conda-forge
# tqdm                      4.64.0                   pypi_0    pypi
# traitlets                 5.1.1              pyhd8ed1ab_0    conda-forge
# typing-extensions         4.1.1                hd8ed1ab_0    conda-forge
# typing_extensions         4.1.1              pyha770c72_0    conda-forge
# tzdata                    2022a                h191b570_0    conda-forge
# unicodedata2              14.0.0           py39hb18efdd_1    conda-forge
# urllib3                   1.24.3                   pypi_0    pypi
# wcwidth                   0.2.5              pyh9f0ad1d_2    conda-forge
# webencodings              0.5.1                      py_1    conda-forge
# websocket-client          1.3.2              pyhd8ed1ab_0    conda-forge
# werkzeug                  2.1.1                    pypi_0    pypi
# wheel                     0.37.1             pyhd8ed1ab_0    conda-forge
# widgetsnbextension        3.6.0            py39h2804cbe_0    conda-forge
# wrapt                     1.14.0                   pypi_0    pypi
# xorg-libxau               1.0.9                h27ca646_0    conda-forge
# xorg-libxdmcp             1.1.3                h27ca646_0    conda-forge
# xz                        5.2.5                h642e427_1    conda-forge
# yaml                      0.2.5                h3422bc3_2    conda-forge
# yapf                      0.32.0                   pypi_0    pypi
# yarl                      1.7.2            py39hb18efdd_2    conda-forge
# zeromq                    4.3.4                hbdafb3b_1    conda-forge
# zipp                      3.8.0              pyhd8ed1ab_0    conda-forge
# zlib                      1.2.11            h90dfc92_1014    conda-forge
# zstd                      1.5.2                h861e0a7_0    conda-forge

# %%
# !python -m segm.train --log-dir $DATASET_LOCALE_CUSTOM --dataset ade20k --backbone vit_tiny_patch16_384 --decoder mask_transformer
# Out:
# libc++abi: terminating with uncaught exception of type std::length_error: vector

# %%
import torch 
torch.distributed.is_available()
# Out:
# False

# %%
# !pip list
# Out:
# Package                       Version
# ----------------------------- -------------------
# absl-py                       1.0.0
# addict                        2.4.0
# aiohttp                       3.8.1
# aiosignal                     1.2.0
# anyio                         3.5.0
# appnope                       0.1.3
# argon2-cffi                   21.3.0
# argon2-cffi-bindings          21.2.0
# asttokens                     2.0.5
# astunparse                    1.6.3
# async-timeout                 4.0.2
# attrs                         21.4.0
# Babel                         2.9.1
# backcall                      0.2.0
# backports.functools-lru-cache 1.6.4
# beautifulsoup4                4.10.0
# bleach                        4.1.0
# brotlipy                      0.7.0
# cached-property               1.5.2
# cachetools                    5.0.0
# certifi                       2021.10.8
# cffi                          1.15.0
# chardet                       3.0.4
# charset-normalizer            2.0.12
# click                         8.1.2
# cryptography                  36.0.2
# cycler                        0.11.0
# debugpy                       1.5.1
# decorator                     5.1.1
# defusedxml                    0.7.1
# einops                        0.4.1
# entrypoints                   0.4
# executing                     0.8.3
# fastjsonschema                2.15.3
# flatbuffers                   2.0
# flit_core                     3.7.1
# fonttools                     4.31.2
# frozenlist                    1.3.0
# future                        0.18.2
# gast                          0.5.3
# google-auth                   2.6.2
# google-auth-oauthlib          0.4.6
# google-colab                  1.0.0
# google-pasta                  0.2.0
# grpcio                        1.45.0
# h5py                          3.6.0
# idna                          3.3
# importlib-metadata            4.11.3
# importlib-resources           5.6.0
# ipykernel                     6.12.1
# ipython                       8.2.0
# ipython-genutils              0.2.0
# ipywidgets                    7.7.0
# jedi                          0.18.1
# Jinja2                        3.1.1
# joblib                        1.1.0
# json5                         0.9.5
# jsonschema                    4.4.0
# jupyter                       1.0.0
# jupyter-client                7.2.1
# jupyter-console               6.4.3
# jupyter-core                  4.9.2
# jupyter-http-over-ws          0.0.8
# jupyter-server                1.16.0
# jupyterlab                    3.3.2
# jupyterlab-pygments           0.1.2
# jupyterlab-server             2.12.0
# jupyterlab-widgets            1.1.0
# keras                         2.8.0
# Keras-Preprocessing           1.1.2
# kiwisolver                    1.4.2
# libclang                      13.0.0
# Markdown                      3.3.6
# MarkupSafe                    2.1.1
# matplotlib                    3.5.1
# matplotlib-inline             0.1.3
# mistune                       0.8.4
# mmcv                          1.3.8
# mmsegmentation                0.14.1
# multidict                     6.0.2
# munkres                       1.1.4
# nbclassic                     0.3.7
# nbclient                      0.5.13
# nbconvert                     6.4.5
# nbformat                      5.3.0
# nest-asyncio                  1.5.5
# notebook                      6.4.10
# notebook-shim                 0.1.0
# numpy                         1.21.5
# oauthlib                      3.2.0
# opencv-python                 4.5.5.64
# opt-einsum                    3.3.0
# packaging                     21.3
# pandas                        1.4.2
# pandocfilters                 1.5.0
# parso                         0.8.3
# pexpect                       4.8.0
# pickleshare                   0.7.5
# Pillow                        9.1.0
# pip                           22.0.4
# portpicker                    1.5.0
# prettytable                   3.2.0
# prometheus-client             0.14.0
# prompt-toolkit                3.0.29
# protobuf                      3.20.0
# psutil                        5.9.0
# ptyprocess                    0.7.0
# pure-eval                     0.2.2
# pyasn1                        0.4.8
# pyasn1-modules                0.2.8
# pycparser                     2.21
# Pygments                      2.11.2
# pyOpenSSL                     22.0.0
# pyparsing                     3.0.7
# pyrsistent                    0.18.1
# PySocks                       1.7.1
# python-dateutil               2.8.2
# python-hostlist               1.21
# pytz                          2022.1
# pyu2f                         0.1.5
# PyYAML                        6.0
# pyzmq                         22.3.0
# requests                      2.27.1
# requests-oauthlib             1.3.1
# rsa                           4.8
# scikit-learn                  1.0.2
# scipy                         1.8.0
# segm                          0.0.1
# Send2Trash                    1.8.0
# setuptools                    62.0.0
# simplegeneric                 0.8.1
# six                           1.16.0
# sniffio                       1.2.0
# soupsieve                     2.3.1
# stack-data                    0.2.0
# tensorboard                   2.8.0
# tensorboard-data-server       0.6.1
# tensorboard-plugin-wit        1.8.1
# tensorflow-macos              2.8.0
# tensorflow-metal              0.4.0
# termcolor                     1.1.0
# terminado                     0.13.3
# testpath                      0.6.0
# tf-estimator-nightly          2.8.0.dev2021122109
# threadpoolctl                 3.1.0
# timm                          0.4.12
# torch                         1.10.2
# torch-geometric               2.0.4
# torch-scatter                 2.0.9
# torch-sparse                  0.6.13
# torchvision                   0.12.0
# tornado                       6.1
# tqdm                          4.64.0
# traitlets                     5.1.1
# typing_extensions             4.1.1
# unicodedata2                  14.0.0
# urllib3                       1.26.9
# wcwidth                       0.2.5
# webencodings                  0.5.1
# websocket-client              1.3.2
# Werkzeug                      2.1.1
# wheel                         0.37.1
# widgetsnbextension            3.6.0
# wrapt                         1.14.0
# yapf                          0.32.0
# yarl                          1.7.2
# zipp                          3.8.0
